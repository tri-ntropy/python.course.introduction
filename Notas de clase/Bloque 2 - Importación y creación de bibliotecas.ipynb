# %% [markdown]
# # Importación y creación de bibliotecas

# %%
import math
import random
import modulo

# %%
# from math import *

# %%
math.cos(math.pi / 2)
# Out:
# 6.123233995736766e-17

# %%
def cos(x):
    return math.cos(x)

# %%
lista_val = []
d = (math.pi / 2) / 91
for i in range(92):
    lista_val.append(i * d)

# %%
lista_cos = []
for x in range(92):
    lista_cos.append(cos(lista_val[x]))

lista_cos
# Out:
# [1.0,
#  0.9998510240408495,
#  0.9994041405510704,
#  0.9986594826804561,
#  0.9976172723012476,
#  0.9962778199420265,
#  0.9946415246951927,
#  0.992708874098054,
#  0.9904804439875632,
#  0.9879568983287464,
#  0.9851389890168738,
#  0.9820275556534304,
#  0.9786235252959553,
#  0.9749279121818236,
#  0.970941817426052,
#  0.9666664286932195,
#  0.9621030198436006,
#  0.9572529505536158,
#  0.9521176659107141,
#  0.946698695982806,
#  0.9409976553623765,
#  0.9350162426854148,
#  0.9287562401253023,
#  0.9222195128618104,
#  0.9154080085253664,
#  0.908323756616754,
#  0.9009688679024191,
#  0.8933455337855631,
#  0.8854560256532099,
#  0.877302694199442,
#  0.8688879687250066,
#  0.8602143564135007,
#  0.8512844415843512,
#  0.8421008849228118,
#  0.8326664226872064,
#  0.8229838658936564,
#  0.8130560994785325,
#  0.8028860814388825,
#  0.7924768419510905,
#  0.7818314824680298,
#  0.7709531747949796,
#  0.7598451601445788,
#  0.7485107481711012,
#  0.7369533159843368,
# ...

# %%
d
# Out:
# 0.017261498096647215

# %%
random.randint(1, 6)
# Out:
# 3

# %%
n = 10
lista_num = []
a = 1
b = 285_000
for i in range(n):
    lista_num.append(random.randint(a, b))

lista_num
# Out:
# [154624, 157249, 18623, 282696, 282565, 5086, 39638, 232070, 222339, 140509]

# %%
random.sample(list(range(1, 285001)), 100)
# Out:
# [175222,
#  232377,
#  245876,
#  123387,
#  143000,
#  238344,
#  133984,
#  88588,
#  3840,
#  233091,
#  80297,
#  77897,
#  231862,
#  110335,
#  42722,
#  74244,
#  136246,
#  182378,
#  99510,
#  33340,
#  226585,
#  199722,
#  57054,
#  96618,
#  217295,
#  61561,
#  145146,
#  77165,
#  258111,
#  95907,
#  246862,
#  188751,
#  266594,
#  167132,
#  144957,
#  266116,
#  186058,
#  23562,
#  11043,
#  123690,
#  57626,
#  282417,
#  190741,
#  271570,
#  128640,
#  136339,
#  155073,
#  27389,
#  94604,
#  61100,
#  55169,
#  185409,
#  111167,
#  96174,
#  211308,
#  131807,
#  206066,
#  200962,
#  203577,
#  200258,
#  40029,
#  62779,
#  16492,
#  99022,
#  115765,
#  159068,
#  64435,
#  275287,
#  283438,
#  14908,
#  137374,
#  29564,
#  251332,
#  60498,
#  267276,
#  97748,
#  100021,
#  48097,
#  201581,
#  282583,
#  39147,
#  229858,
#  87301,
#  251469,
#  212102,
#  49304,
#  250956,
#  174079,
#  149968,
#  89705,
#  254373,
#  55809,
#  164460,
#  206448,
# ...

# %%
math
# Out:
# <module 'math' from '/home/tony/conda/envs/sci/lib/python3.12/lib-dynload/math.cpython-312-x86_64-linux-gnu.so'>

# %%
modulo.derivada(lista_cos, d)
# Out:
# [-0.008630534749441518,
#  -0.01725978375669864,
#  -0.034514424927717696,
#  -0.0517587824596129,
#  -0.06898771836299247,
#  -0.08619609924334712,
#  -0.10337879783058074,
#  -0.12053069450668875,
#  -0.13764667883115328,
#  -0.1547216510636143,
#  -0.1717505236833346,
#  -0.1887282229050566,
#  -0.20564969019072976,
#  -0.22250988375671038,
#  -0.23930378007598263,
#  -0.2560263753749228,
#  -0.27267268712418763,
#  -0.28923775552325814,
#  -0.3057166449782199,
#  -0.32210444557235623,
#  -0.3383962745290424,
#  -0.35458727766658404,
#  -0.3706726308445395,
#  -0.3866475414010738,
#  -0.40250724958094414,
#  -0.41824702995367047,
#  -0.43386219282149596,
#  -0.4493480856166931,
#  -0.4647000942877971,
#  -0.4799136446743688,
#  -0.4949842038698936,
#  -0.509907281572351,
#  -0.5246784314221038,
#  -0.5392932523267242,
#  -0.5537473897722877,
#  -0.568036537120809,
#  -0.582156436893433,
#  -0.5961028820389368,
#  -0.609871717187231,
#  -0.6234588398874695,
#  -0.6368602018303817,
# ...

# %%
type(d)
# Out:
# float

# %%
/home/tony/Escritorio/Python Introduction/Notas de clase/Clase 1 - Introducción a Python.md
